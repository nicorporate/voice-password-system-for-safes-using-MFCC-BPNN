# %%
import os
import numpy as np
import scipy
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import pandas
import matplotlib.pyplot as plt
import speechpy

# %%
def normalize_audio(audio):
    audio = audio/np.max(np.abs(audio))
    return audio

def frame_audio(audio, FFT_size = 2048, hop_size = 512, sample_rate=44100):
    audio = np.pad(audio, int(FFT_size/2), mode='reflect')
    frame_len = np.round(sample_rate * hop_size / 1000).astype(int)
    frame_num = int((len(audio) - FFT_size) / frame_len) + 1
    frames = np.zeros((frame_num, FFT_size))
    for n in range(frame_num):
        frames[n] = audio[n*frame_len : n*frame_len+FFT_size]
    return frames

def freq_to_mel(freq):
    return 2595.0 * np.log10(1.0 + freq / 700.0)

def met_to_freq(mels):
    return 700.0 * (10.0**(mels / 2595.0) - 1.0)

def get_filter_points(fmin, fmax, mel_filter_num, FFT_size, sample_rate=44100):
    fmin_mel = freq_to_mel(fmin)
    fmax_mel = freq_to_mel(fmax)    
    mels = np.linspace(fmin_mel, fmax_mel, num=mel_filter_num+2)
    freqs = met_to_freq(mels)    
    return np.floor((FFT_size + 1) / sample_rate * freqs).astype(int), freqs

def get_filters(filter_points, FFT_size):
    filters = np.zeros((len(filter_points)-2, int((FFT_size/2)+1)))
    for n in range(len(filter_points)-2):
        filters[n, filter_points[n] : filter_points[n + 1]] = np.linspace(0, 1, filter_points[n + 1] - filter_points[n])
        filters[n, filter_points[n + 1] : filter_points[n + 2]] = np.linspace(1, 0, filter_points[n + 2] - filter_points[n + 1])
    return filters

def dct(dct_filter_num, filter_len):
    basis = np.empty((dct_filter_num,filter_len))
    basis[0, :] = 1.0 / np.sqrt(filter_len)
    
    samples = np.arange(1, 2 * filter_len, 2) * np.pi / (2.0 * filter_len)

    for i in range(1, dct_filter_num):
        basis[i, :] = np.cos(i * samples) * np.sqrt(2.0 / filter_len)
        
    return basis

# %%
trainpath = "C:/Users/Dataset/"
filename = ["DataLatih/Lock/Lock","DataLatih/Unlock/Unlock"]

# %%
#MFCC Data latih
count = 0
datacount = 720*2 #jumlah data latih
fiturmean = np.empty((40+1, datacount))
for kategori in range(2):
    for i in range(720):
        #open file & get sample rate
        sample_rate, audio = wavfile.read(trainpath + filename[kategori] + " ("+ str(i+1) +").wav")
        print(filename[kategori] + " ("+ str(i+1) +").wav")

        #normalize audio
        if (len(audio.shape) > 1):
            audio1 = normalize_audio(audio[:,0])
        else:
            audio1 = normalize_audio(audio)

        #crop the blank moment 
        threshold=0.1
        awal = 0
        for x in range (len(audio1)):
            if np.abs(audio1[x]) >= threshold:
                awal=x #Data sinyal ke-x sebagai sinyal awal
                break
        audiohasil=audio1[awal:len(audio1)]#mengambil data sinyal mulai dari data ke-x sd data terakhir

        for x in range (len(audiohasil)):
            if np.abs(audiohasil[x]) >=threshold:
                akhir=x #Data sinyal ke-x yg terakhir
        audiohasil2=audiohasil[0:akhir]

        #audio framing
        hop_size = 512 
        FFT_size = 2048
        audio_framed = frame_audio(audiohasil2, FFT_size=FFT_size, hop_size=hop_size, sample_rate=sample_rate)

        #windowing
        window = get_window("hamming", FFT_size, fftbins=True)
        audio_win = audio_framed * window

        #fft
        audio_winT = np.transpose(audio_win)
        audio_fft = np.empty((int(1 + FFT_size // 2), audio_winT.shape[1]), dtype=np.complex64, order='F')
        for n in range(audio_fft.shape[1]):
            audio_fft[:, n] = fft.fft(audio_winT[:, n], axis=0)[:audio_fft.shape[0]]
        audio_fft = np.transpose(audio_fft)

        #power spectrum
        audio_power = np.square(np.abs(audio_fft))

        #mel filter bank
        freq_min = 0
        freq_high = sample_rate / 2
        mel_filter_num = 10
        filter_points, mel_freqs = get_filter_points(freq_min, freq_high, mel_filter_num, FFT_size, sample_rate)
        filters = get_filters(filter_points, FFT_size)
        enorm = 2.0 / (mel_freqs[2:mel_filter_num+2] - mel_freqs[:mel_filter_num])
        filters *= enorm[:, np.newaxis]

        audio_filtered = np.dot(filters, np.transpose(audio_power))
        audio_log = 10.0 * np.log10(audio_filtered)

        #DCT & cepstral coefficient
        dct_filter_num = 40
        dct_filters = dct(dct_filter_num, mel_filter_num)
        cepstral_coefficents = np.dot(dct_filters, audio_log)

        #normalizing cepstral coefficient value using CMVN method ((Xn-Xmean)/Variance)
        cepstral_coefficents = speechpy.processing.cmvn(cepstral_coefficents,True)

        #ceptral coeffienct dirata2kan
        for xpos in range(len(cepstral_coefficents)):
            sigmax = 0
            for xn in cepstral_coefficents[xpos,:]:
                sigmax += xn
            fiturmean[xpos,count] = sigmax/len(np.transpose(cepstral_coefficents))
        fiturmean[-1,count] = kategori

        count+=1
indextable = []
for i in range(40):
    indextable.append("fitur" + str(i+1))
indextable.append("klasifikasi")

df = pandas.DataFrame(np.transpose(fiturmean),columns=indextable)
df.to_excel("ekstraksilatih.xlsx", index=False)
# Out:
# DataLatih/Lock/Lock (1).wav
# DataLatih/Lock/Lock (2).wav
# DataLatih/Lock/Lock (3).wav
# DataLatih/Lock/Lock (4).wav
# DataLatih/Lock/Lock (5).wav
# DataLatih/Lock/Lock (6).wav
# DataLatih/Lock/Lock (7).wav
# DataLatih/Lock/Lock (8).wav
# DataLatih/Lock/Lock (9).wav
# DataLatih/Lock/Lock (10).wav
# DataLatih/Lock/Lock (11).wav
# DataLatih/Lock/Lock (12).wav
# DataLatih/Lock/Lock (13).wav
# DataLatih/Lock/Lock (14).wav
# DataLatih/Lock/Lock (15).wav
# DataLatih/Lock/Lock (16).wav
# DataLatih/Lock/Lock (17).wav
# DataLatih/Lock/Lock (18).wav
# DataLatih/Lock/Lock (19).wav
# DataLatih/Lock/Lock (20).wav
# DataLatih/Lock/Lock (21).wav
# DataLatih/Lock/Lock (22).wav
# DataLatih/Lock/Lock (23).wav
# DataLatih/Lock/Lock (24).wav
# DataLatih/Lock/Lock (25).wav
# DataLatih/Lock/Lock (26).wav
# DataLatih/Lock/Lock (27).wav
# DataLatih/Lock/Lock (28).wav
# DataLatih/Lock/Lock (29).wav
# DataLatih/Lock/Lock (30).wav
# DataLatih/Lock/Lock (31).wav
# DataLatih/Lock/Lock (32).wav
# DataLatih/Lock/Lock (33).wav
# DataLatih/Lock/Lock (34).wav
# DataLatih/Lock/Lock (35).wav
# DataLatih/Lock/Lock (36).wav
# DataLatih/Lock/Lock (37).wav
# DataLatih/Lock/Lock (38).wav
# DataLatih/Lock/Lock (39).wav
# DataLatih/Lock/Lock (40).wav
# DataLatih/Lock/Lock (41).wav
# DataLatih/Lock/Lock (42).wav
# DataLatih/Lock/Lock (43).wav
# DataLatih/Lock/Lock (44).wav
# DataLatih/Lock/Lock (45).wav
# DataLatih/Lock/Lock (46).wav
# DataLatih/Lock/Lock (47).wav
# DataLatih/Lock/Lock (48).wav
# DataLatih/Lock/Lock (49).wav
# DataLatih/Lock/Lock (50).wav
# DataLatih/Lock/Lock (51).wav
# DataLatih/Lock/Lock (52).wav
# DataLatih/Lock/Lock (53).wav
# DataLatih/Lock/Lock (54).wav
# DataLatih/Lock/Lock (55).wav
# DataLatih/Lock/Lock (56).wav
# DataLatih/Lock/Lock (57).wav
# DataLatih/Lock/Lock (58).wav
# DataLatih/Lock/Lock (59).wav
# DataLatih/Lock/Lock (60).wav
# DataLatih/Lock/Lock (61).wav
# DataLatih/Lock/Lock (62).wav
# DataLatih/Lock/Lock (63).wav
# DataLatih/Lock/Lock (64).wav
# DataLatih/Lock/Lock (65).wav
# DataLatih/Lock/Lock (66).wav
# DataLatih/Lock/Lock (67).wav
# DataLatih/Lock/Lock (68).wav
# DataLatih/Lock/Lock (69).wav
# DataLatih/Lock/Lock (70).wav
# DataLatih/Lock/Lock (71).wav
# DataLatih/Lock/Lock (72).wav
# DataLatih/Lock/Lock (73).wav
# DataLatih/Lock/Lock (74).wav
# DataLatih/Lock/Lock (75).wav
# DataLatih/Lock/Lock (76).wav
# DataLatih/Lock/Lock (77).wav
# DataLatih/Lock/Lock (78).wav
# DataLatih/Lock/Lock (79).wav
# DataLatih/Lock/Lock (80).wav
# DataLatih/Lock/Lock (81).wav
# DataLatih/Lock/Lock (82).wav
# DataLatih/Lock/Lock (83).wav
# DataLatih/Lock/Lock (84).wav
# DataLatih/Lock/Lock (85).wav
# DataLatih/Lock/Lock (86).wav
# DataLatih/Lock/Lock (87).wav
# DataLatih/Lock/Lock (88).wav
# DataLatih/Lock/Lock (89).wav
# DataLatih/Lock/Lock (90).wav
# DataLatih/Lock/Lock (91).wav
# DataLatih/Lock/Lock (92).wav
# DataLatih/Lock/Lock (93).wav
# DataLatih/Lock/Lock (94).wav
# DataLatih/Lock/Lock (95).wav
# DataLatih/Lock/Lock (96).wav
# DataLatih/Lock/Lock (97).wav
# DataLatih/Lock/Lock (98).wav
# DataLatih/Lock/Lock (99).wav
# DataLatih/Lock/Lock (100).wav
# DataLatih/Lock/Lock (101).wav
# DataLatih/Lock/Lock (102).wav
# DataLatih/Lock/Lock (103).wav
# DataLatih/Lock/Lock (104).wav
# DataLatih/Lock/Lock (105).wav
# DataLatih/Lock/Lock (106).wav
# DataLatih/Lock/Lock (107).wav
# DataLatih/Lock/Lock (108).wav
# DataLatih/Lock/Lock (109).wav
# DataLatih/Lock/Lock (110).wav
# DataLatih/Lock/Lock (111).wav
# DataLatih/Lock/Lock (112).wav
# DataLatih/Lock/Lock (113).wav
# DataLatih/Lock/Lock (114).wav
# DataLatih/Lock/Lock (115).wav
# DataLatih/Lock/Lock (116).wav
# DataLatih/Lock/Lock (117).wav
# DataLatih/Lock/Lock (118).wav
# DataLatih/Lock/Lock (119).wav
# DataLatih/Lock/Lock (120).wav
# DataLatih/Lock/Lock (121).wav
# DataLatih/Lock/Lock (122).wav
# DataLatih/Lock/Lock (123).wav
# DataLatih/Lock/Lock (124).wav
# DataLatih/Lock/Lock (125).wav
# DataLatih/Lock/Lock (126).wav
# DataLatih/Lock/Lock (127).wav
# DataLatih/Lock/Lock (128).wav
# DataLatih/Lock/Lock (129).wav
# DataLatih/Lock/Lock (130).wav
# DataLatih/Lock/Lock (131).wav
# DataLatih/Lock/Lock (132).wav
# DataLatih/Lock/Lock (133).wav
# DataLatih/Lock/Lock (134).wav
# DataLatih/Lock/Lock (135).wav
# DataLatih/Lock/Lock (136).wav
# DataLatih/Lock/Lock (137).wav
# DataLatih/Lock/Lock (138).wav
# DataLatih/Lock/Lock (139).wav
# DataLatih/Lock/Lock (140).wav
# DataLatih/Lock/Lock (141).wav
# DataLatih/Lock/Lock (142).wav
# DataLatih/Lock/Lock (143).wav
# DataLatih/Lock/Lock (144).wav
# DataLatih/Lock/Lock (145).wav
# DataLatih/Lock/Lock (146).wav
# DataLatih/Lock/Lock (147).wav
# DataLatih/Lock/Lock (148).wav
# DataLatih/Lock/Lock (149).wav
# DataLatih/Lock/Lock (150).wav
# DataLatih/Lock/Lock (151).wav
# DataLatih/Lock/Lock (152).wav
# DataLatih/Lock/Lock (153).wav
# DataLatih/Lock/Lock (154).wav
# DataLatih/Lock/Lock (155).wav
# DataLatih/Lock/Lock (156).wav
# DataLatih/Lock/Lock (157).wav
# DataLatih/Lock/Lock (158).wav
# DataLatih/Lock/Lock (159).wav
# DataLatih/Lock/Lock (160).wav
# DataLatih/Lock/Lock (161).wav
# DataLatih/Lock/Lock (162).wav
# DataLatih/Lock/Lock (163).wav
# DataLatih/Lock/Lock (164).wav
# DataLatih/Lock/Lock (165).wav
# DataLatih/Lock/Lock (166).wav
# DataLatih/Lock/Lock (167).wav
# DataLatih/Lock/Lock (168).wav
# DataLatih/Lock/Lock (169).wav
# DataLatih/Lock/Lock (170).wav
# DataLatih/Lock/Lock (171).wav
# DataLatih/Lock/Lock (172).wav
# DataLatih/Lock/Lock (173).wav
# DataLatih/Lock/Lock (174).wav
# DataLatih/Lock/Lock (175).wav
# DataLatih/Lock/Lock (176).wav
# DataLatih/Lock/Lock (177).wav
# DataLatih/Lock/Lock (178).wav
# DataLatih/Lock/Lock (179).wav
# DataLatih/Lock/Lock (180).wav
# DataLatih/Lock/Lock (181).wav
# DataLatih/Lock/Lock (182).wav
# DataLatih/Lock/Lock (183).wav
# DataLatih/Lock/Lock (184).wav
# DataLatih/Lock/Lock (185).wav
# DataLatih/Lock/Lock (186).wav
# DataLatih/Lock/Lock (187).wav
# DataLatih/Lock/Lock (188).wav
# DataLatih/Lock/Lock (189).wav
# DataLatih/Lock/Lock (190).wav
# DataLatih/Lock/Lock (191).wav
# DataLatih/Lock/Lock (192).wav
# DataLatih/Lock/Lock (193).wav
# DataLatih/Lock/Lock (194).wav
# DataLatih/Lock/Lock (195).wav
# DataLatih/Lock/Lock (196).wav
# DataLatih/Lock/Lock (197).wav
# DataLatih/Lock/Lock (198).wav
# DataLatih/Lock/Lock (199).wav
# DataLatih/Lock/Lock (200).wav
# DataLatih/Lock/Lock (201).wav
# DataLatih/Lock/Lock (202).wav
# DataLatih/Lock/Lock (203).wav
# DataLatih/Lock/Lock (204).wav
# DataLatih/Lock/Lock (205).wav
# DataLatih/Lock/Lock (206).wav
# DataLatih/Lock/Lock (207).wav
# DataLatih/Lock/Lock (208).wav
# DataLatih/Lock/Lock (209).wav
# DataLatih/Lock/Lock (210).wav
# DataLatih/Lock/Lock (211).wav
# DataLatih/Lock/Lock (212).wav
# DataLatih/Lock/Lock (213).wav
# DataLatih/Lock/Lock (214).wav
# DataLatih/Lock/Lock (215).wav
# DataLatih/Lock/Lock (216).wav
# DataLatih/Lock/Lock (217).wav
# DataLatih/Lock/Lock (218).wav
# DataLatih/Lock/Lock (219).wav
# DataLatih/Lock/Lock (220).wav
# DataLatih/Lock/Lock (221).wav
# DataLatih/Lock/Lock (222).wav
# DataLatih/Lock/Lock (223).wav
# DataLatih/Lock/Lock (224).wav
# DataLatih/Lock/Lock (225).wav
# DataLatih/Lock/Lock (226).wav
# DataLatih/Lock/Lock (227).wav
# DataLatih/Lock/Lock (228).wav
# DataLatih/Lock/Lock (229).wav
# DataLatih/Lock/Lock (230).wav
# DataLatih/Lock/Lock (231).wav
# DataLatih/Lock/Lock (232).wav
# DataLatih/Lock/Lock (233).wav
# DataLatih/Lock/Lock (234).wav
# DataLatih/Lock/Lock (235).wav
# DataLatih/Lock/Lock (236).wav
# DataLatih/Lock/Lock (237).wav
# DataLatih/Lock/Lock (238).wav
# DataLatih/Lock/Lock (239).wav
# DataLatih/Lock/Lock (240).wav
# DataLatih/Lock/Lock (241).wav
# DataLatih/Lock/Lock (242).wav
# DataLatih/Lock/Lock (243).wav
# DataLatih/Lock/Lock (244).wav
# DataLatih/Lock/Lock (245).wav
# DataLatih/Lock/Lock (246).wav
# DataLatih/Lock/Lock (247).wav
# DataLatih/Lock/Lock (248).wav
# DataLatih/Lock/Lock (249).wav
# DataLatih/Lock/Lock (250).wav
# DataLatih/Lock/Lock (251).wav
# DataLatih/Lock/Lock (252).wav
# DataLatih/Lock/Lock (253).wav
# DataLatih/Lock/Lock (254).wav
# DataLatih/Lock/Lock (255).wav
# DataLatih/Lock/Lock (256).wav
# DataLatih/Lock/Lock (257).wav
# DataLatih/Lock/Lock (258).wav
# DataLatih/Lock/Lock (259).wav
# DataLatih/Lock/Lock (260).wav
# DataLatih/Lock/Lock (261).wav
# DataLatih/Lock/Lock (262).wav
# DataLatih/Lock/Lock (263).wav
# DataLatih/Lock/Lock (264).wav
# DataLatih/Lock/Lock (265).wav
# DataLatih/Lock/Lock (266).wav
# DataLatih/Lock/Lock (267).wav
# DataLatih/Lock/Lock (268).wav
# DataLatih/Lock/Lock (269).wav
# DataLatih/Lock/Lock (270).wav
# DataLatih/Lock/Lock (271).wav
# DataLatih/Lock/Lock (272).wav
# DataLatih/Lock/Lock (273).wav
# DataLatih/Lock/Lock (274).wav
# DataLatih/Lock/Lock (275).wav
# DataLatih/Lock/Lock (276).wav
# DataLatih/Lock/Lock (277).wav
# DataLatih/Lock/Lock (278).wav
# DataLatih/Lock/Lock (279).wav
# DataLatih/Lock/Lock (280).wav
# DataLatih/Lock/Lock (281).wav
# DataLatih/Lock/Lock (282).wav
# DataLatih/Lock/Lock (283).wav
# DataLatih/Lock/Lock (284).wav
# DataLatih/Lock/Lock (285).wav
# DataLatih/Lock/Lock (286).wav
# DataLatih/Lock/Lock (287).wav
# DataLatih/Lock/Lock (288).wav
# DataLatih/Lock/Lock (289).wav
# DataLatih/Lock/Lock (290).wav
# DataLatih/Lock/Lock (291).wav
# DataLatih/Lock/Lock (292).wav
# DataLatih/Lock/Lock (293).wav
# DataLatih/Lock/Lock (294).wav
# DataLatih/Lock/Lock (295).wav
# DataLatih/Lock/Lock (296).wav
# DataLatih/Lock/Lock (297).wav
# DataLatih/Lock/Lock (298).wav
# DataLatih/Lock/Lock (299).wav
# DataLatih/Lock/Lock (300).wav
# DataLatih/Lock/Lock (301).wav
# DataLatih/Lock/Lock (302).wav
# DataLatih/Lock/Lock (303).wav
# DataLatih/Lock/Lock (304).wav
# DataLatih/Lock/Lock (305).wav
# DataLatih/Lock/Lock (306).wav
# DataLatih/Lock/Lock (307).wav
# DataLatih/Lock/Lock (308).wav
# DataLatih/Lock/Lock (309).wav
# DataLatih/Lock/Lock (310).wav
# DataLatih/Lock/Lock (311).wav
# DataLatih/Lock/Lock (312).wav
# DataLatih/Lock/Lock (313).wav
# DataLatih/Lock/Lock (314).wav
# DataLatih/Lock/Lock (315).wav
# DataLatih/Lock/Lock (316).wav
# DataLatih/Lock/Lock (317).wav
# DataLatih/Lock/Lock (318).wav
# DataLatih/Lock/Lock (319).wav
# DataLatih/Lock/Lock (320).wav
# DataLatih/Lock/Lock (321).wav
# DataLatih/Lock/Lock (322).wav
# DataLatih/Lock/Lock (323).wav
# DataLatih/Lock/Lock (324).wav
# DataLatih/Lock/Lock (325).wav
# DataLatih/Lock/Lock (326).wav
# DataLatih/Lock/Lock (327).wav
# DataLatih/Lock/Lock (328).wav
# DataLatih/Lock/Lock (329).wav
# DataLatih/Lock/Lock (330).wav
# DataLatih/Lock/Lock (331).wav
# DataLatih/Lock/Lock (332).wav
# DataLatih/Lock/Lock (333).wav
# DataLatih/Lock/Lock (334).wav
# DataLatih/Lock/Lock (335).wav
# DataLatih/Lock/Lock (336).wav
# DataLatih/Lock/Lock (337).wav
# DataLatih/Lock/Lock (338).wav
# DataLatih/Lock/Lock (339).wav
# DataLatih/Lock/Lock (340).wav
# DataLatih/Lock/Lock (341).wav
# DataLatih/Lock/Lock (342).wav
# DataLatih/Lock/Lock (343).wav
# DataLatih/Lock/Lock (344).wav
# DataLatih/Lock/Lock (345).wav
# DataLatih/Lock/Lock (346).wav
# DataLatih/Lock/Lock (347).wav
# DataLatih/Lock/Lock (348).wav
# DataLatih/Lock/Lock (349).wav
# DataLatih/Lock/Lock (350).wav
# DataLatih/Lock/Lock (351).wav
# DataLatih/Lock/Lock (352).wav
# DataLatih/Lock/Lock (353).wav
# DataLatih/Lock/Lock (354).wav
# DataLatih/Lock/Lock (355).wav
# DataLatih/Lock/Lock (356).wav
# DataLatih/Lock/Lock (357).wav
# DataLatih/Lock/Lock (358).wav
# DataLatih/Lock/Lock (359).wav
# DataLatih/Lock/Lock (360).wav
# DataLatih/Lock/Lock (361).wav
# DataLatih/Lock/Lock (362).wav
# DataLatih/Lock/Lock (363).wav
# DataLatih/Lock/Lock (364).wav
# DataLatih/Lock/Lock (365).wav
# DataLatih/Lock/Lock (366).wav
# DataLatih/Lock/Lock (367).wav
# DataLatih/Lock/Lock (368).wav
# DataLatih/Lock/Lock (369).wav
# DataLatih/Lock/Lock (370).wav
# DataLatih/Lock/Lock (371).wav
# DataLatih/Lock/Lock (372).wav
# DataLatih/Lock/Lock (373).wav
# DataLatih/Lock/Lock (374).wav
# DataLatih/Lock/Lock (375).wav
# DataLatih/Lock/Lock (376).wav
# DataLatih/Lock/Lock (377).wav
# DataLatih/Lock/Lock (378).wav
# DataLatih/Lock/Lock (379).wav
# DataLatih/Lock/Lock (380).wav
# DataLatih/Lock/Lock (381).wav
# DataLatih/Lock/Lock (382).wav
# DataLatih/Lock/Lock (383).wav
# DataLatih/Lock/Lock (384).wav
# DataLatih/Lock/Lock (385).wav
# DataLatih/Lock/Lock (386).wav
# DataLatih/Lock/Lock (387).wav
# DataLatih/Lock/Lock (388).wav
# DataLatih/Lock/Lock (389).wav
# DataLatih/Lock/Lock (390).wav
# DataLatih/Lock/Lock (391).wav
# DataLatih/Lock/Lock (392).wav
# DataLatih/Lock/Lock (393).wav
# DataLatih/Lock/Lock (394).wav
# DataLatih/Lock/Lock (395).wav
# DataLatih/Lock/Lock (396).wav
# DataLatih/Lock/Lock (397).wav
# DataLatih/Lock/Lock (398).wav
# DataLatih/Lock/Lock (399).wav
# DataLatih/Lock/Lock (400).wav
# DataLatih/Lock/Lock (401).wav
# DataLatih/Lock/Lock (402).wav
# DataLatih/Lock/Lock (403).wav
# DataLatih/Lock/Lock (404).wav
# DataLatih/Lock/Lock (405).wav
# DataLatih/Lock/Lock (406).wav
# DataLatih/Lock/Lock (407).wav
# DataLatih/Lock/Lock (408).wav
# DataLatih/Lock/Lock (409).wav
# DataLatih/Lock/Lock (410).wav
# DataLatih/Lock/Lock (411).wav
# DataLatih/Lock/Lock (412).wav
# DataLatih/Lock/Lock (413).wav
# DataLatih/Lock/Lock (414).wav
# DataLatih/Lock/Lock (415).wav
# DataLatih/Lock/Lock (416).wav
# DataLatih/Lock/Lock (417).wav
# DataLatih/Lock/Lock (418).wav
# DataLatih/Lock/Lock (419).wav
# DataLatih/Lock/Lock (420).wav
# DataLatih/Lock/Lock (421).wav
# DataLatih/Lock/Lock (422).wav
# DataLatih/Lock/Lock (423).wav
# DataLatih/Lock/Lock (424).wav
# DataLatih/Lock/Lock (425).wav
# DataLatih/Lock/Lock (426).wav
# DataLatih/Lock/Lock (427).wav
# DataLatih/Lock/Lock (428).wav

# %%
#buat data uji
count = 0
datacount = 180*2 #jumlah data latih
fiturmean = np.empty((40+1, datacount))
for kategori in range(2):
    for i in range(180):
        #open file & get sample rate
        sample_rate, audio = wavfile.read(trainpath + filename[kategori] + " ("+ str(i+721) +").wav")
        print(filename[kategori] + " ("+ str(i+721) +").wav")

        #normalisasi audio
        if (len(audio.shape) > 1):
            audio1 = normalize_audio(audio[:,0]) 
        else:
            audio1 = normalize_audio(audio)

        #memotong bagian silence
        threshold=0.1
        awal = 0
        for x in range (len(audio1)):
            if np.abs(audio1[x]) >= threshold:
                awal=x 
                break
        audiohasil=audio1[awal:len(audio1)]

        for x in range (len(audiohasil)):
            if np.abs(audiohasil[x]) >=threshold:
                akhir=x 
        audiohasil2=audiohasil[0:akhir]

        #audio framing
        hop_size = 512
        FFT_size = 2048
        audio_framed = frame_audio(audiohasil2, FFT_size=FFT_size, hop_size=hop_size, sample_rate=sample_rate)

        #windowing
        window = get_window("hamming", FFT_size, fftbins=True)
        audio_win = audio_framed * window

        #fft
        audio_winT = np.transpose(audio_win)
        audio_fft = np.empty((int(1 + FFT_size // 2), audio_winT.shape[1]), dtype=np.complex64, order='F')
        for n in range(audio_fft.shape[1]):
            audio_fft[:, n] = fft.fft(audio_winT[:, n], axis=0)[:audio_fft.shape[0]]
        audio_fft = np.transpose(audio_fft)

        #power spectrum
        audio_power = np.square(np.abs(audio_fft))

        #creating mel filter bank
        freq_min = 0
        freq_high = sample_rate / 2
        mel_filter_num = 10
        filter_points, mel_freqs = get_filter_points(freq_min, freq_high, mel_filter_num, FFT_size, sample_rate)
        filters = get_filters(filter_points, FFT_size)
        enorm = 2.0 / (mel_freqs[2:mel_filter_num+2] - mel_freqs[:mel_filter_num])
        filters *= enorm[:, np.newaxis]

        audio_filtered = np.dot(filters, np.transpose(audio_power))
        audio_log = 10.0 * np.log10(audio_filtered)

        #create cepstral coefficient
        dct_filter_num = 40
        dct_filters = dct(dct_filter_num, mel_filter_num)
        cepstral_coefficents = np.dot(dct_filters, audio_log)

        #normalizing cepstral coefficient value using CMVN method ((Xn-Xmean)/Variance)
        cepstral_coefficents = speechpy.processing.cmvn(cepstral_coefficents,True)

        #ceptral coeffienct dirata2kan
        for xpos in range(len(cepstral_coefficents)):
            sigmax = 0
            for xn in cepstral_coefficents[xpos,:]:
                sigmax += xn
            fiturmean[xpos,count] = sigmax/len(np.transpose(cepstral_coefficents))
        fiturmean[-1,count] = kategori

        count+=1
indextable = []
for i in range(40):
    indextable.append("fitur" + str(i+1))
indextable.append("klasifikasi")

df = pandas.DataFrame(np.transpose(fiturmean),columns=indextable)
df.to_excel("ekstraksiuji.xlsx", index=False)
# Out:
# DataLatih/Lock/Lock (721).wav
# DataLatih/Lock/Lock (722).wav
# DataLatih/Lock/Lock (723).wav
# DataLatih/Lock/Lock (724).wav
# DataLatih/Lock/Lock (725).wav
# DataLatih/Lock/Lock (726).wav
# DataLatih/Lock/Lock (727).wav
# DataLatih/Lock/Lock (728).wav
# DataLatih/Lock/Lock (729).wav
# DataLatih/Lock/Lock (730).wav
# DataLatih/Lock/Lock (731).wav
# DataLatih/Lock/Lock (732).wav
# DataLatih/Lock/Lock (733).wav
# DataLatih/Lock/Lock (734).wav
# DataLatih/Lock/Lock (735).wav
# DataLatih/Lock/Lock (736).wav
# DataLatih/Lock/Lock (737).wav
# DataLatih/Lock/Lock (738).wav
# DataLatih/Lock/Lock (739).wav
# DataLatih/Lock/Lock (740).wav
# DataLatih/Lock/Lock (741).wav
# DataLatih/Lock/Lock (742).wav
# DataLatih/Lock/Lock (743).wav
# DataLatih/Lock/Lock (744).wav
# DataLatih/Lock/Lock (745).wav
# DataLatih/Lock/Lock (746).wav
# DataLatih/Lock/Lock (747).wav
# DataLatih/Lock/Lock (748).wav
# DataLatih/Lock/Lock (749).wav
# DataLatih/Lock/Lock (750).wav
# DataLatih/Lock/Lock (751).wav
# DataLatih/Lock/Lock (752).wav
# DataLatih/Lock/Lock (753).wav
# DataLatih/Lock/Lock (754).wav
# DataLatih/Lock/Lock (755).wav
# DataLatih/Lock/Lock (756).wav
# DataLatih/Lock/Lock (757).wav
# DataLatih/Lock/Lock (758).wav
# DataLatih/Lock/Lock (759).wav
# DataLatih/Lock/Lock (760).wav
# DataLatih/Lock/Lock (761).wav
# DataLatih/Lock/Lock (762).wav
# DataLatih/Lock/Lock (763).wav
# DataLatih/Lock/Lock (764).wav
# DataLatih/Lock/Lock (765).wav
# DataLatih/Lock/Lock (766).wav
# DataLatih/Lock/Lock (767).wav
# DataLatih/Lock/Lock (768).wav
# DataLatih/Lock/Lock (769).wav
# DataLatih/Lock/Lock (770).wav
# DataLatih/Lock/Lock (771).wav
# DataLatih/Lock/Lock (772).wav
# DataLatih/Lock/Lock (773).wav
# DataLatih/Lock/Lock (774).wav
# DataLatih/Lock/Lock (775).wav
# DataLatih/Lock/Lock (776).wav
# DataLatih/Lock/Lock (777).wav
# DataLatih/Lock/Lock (778).wav
# DataLatih/Lock/Lock (779).wav
# DataLatih/Lock/Lock (780).wav
# DataLatih/Lock/Lock (781).wav
# DataLatih/Lock/Lock (782).wav
# DataLatih/Lock/Lock (783).wav
# DataLatih/Lock/Lock (784).wav
# DataLatih/Lock/Lock (785).wav
# DataLatih/Lock/Lock (786).wav
# DataLatih/Lock/Lock (787).wav
# DataLatih/Lock/Lock (788).wav
# DataLatih/Lock/Lock (789).wav
# DataLatih/Lock/Lock (790).wav
# DataLatih/Lock/Lock (791).wav
# DataLatih/Lock/Lock (792).wav
# DataLatih/Lock/Lock (793).wav
# DataLatih/Lock/Lock (794).wav
# DataLatih/Lock/Lock (795).wav
# DataLatih/Lock/Lock (796).wav
# DataLatih/Lock/Lock (797).wav
# DataLatih/Lock/Lock (798).wav
# DataLatih/Lock/Lock (799).wav
# DataLatih/Lock/Lock (800).wav
# DataLatih/Lock/Lock (801).wav
# DataLatih/Lock/Lock (802).wav
# DataLatih/Lock/Lock (803).wav
# DataLatih/Lock/Lock (804).wav
# DataLatih/Lock/Lock (805).wav
# DataLatih/Lock/Lock (806).wav
# DataLatih/Lock/Lock (807).wav
# DataLatih/Lock/Lock (808).wav
# DataLatih/Lock/Lock (809).wav
# DataLatih/Lock/Lock (810).wav
# DataLatih/Lock/Lock (811).wav
# DataLatih/Lock/Lock (812).wav
# DataLatih/Lock/Lock (813).wav
# DataLatih/Lock/Lock (814).wav
# DataLatih/Lock/Lock (815).wav
# DataLatih/Lock/Lock (816).wav
# DataLatih/Lock/Lock (817).wav
# DataLatih/Lock/Lock (818).wav
# DataLatih/Lock/Lock (819).wav
# DataLatih/Lock/Lock (820).wav
# DataLatih/Lock/Lock (821).wav
# DataLatih/Lock/Lock (822).wav
# DataLatih/Lock/Lock (823).wav
# DataLatih/Lock/Lock (824).wav
# DataLatih/Lock/Lock (825).wav
# DataLatih/Lock/Lock (826).wav
# DataLatih/Lock/Lock (827).wav
# DataLatih/Lock/Lock (828).wav
# DataLatih/Lock/Lock (829).wav
# DataLatih/Lock/Lock (830).wav
# DataLatih/Lock/Lock (831).wav
# DataLatih/Lock/Lock (832).wav
# DataLatih/Lock/Lock (833).wav
# DataLatih/Lock/Lock (834).wav
# DataLatih/Lock/Lock (835).wav
# DataLatih/Lock/Lock (836).wav
# DataLatih/Lock/Lock (837).wav
# DataLatih/Lock/Lock (838).wav
# DataLatih/Lock/Lock (839).wav
# DataLatih/Lock/Lock (840).wav
# DataLatih/Lock/Lock (841).wav
# DataLatih/Lock/Lock (842).wav
# DataLatih/Lock/Lock (843).wav
# DataLatih/Lock/Lock (844).wav
# DataLatih/Lock/Lock (845).wav
# DataLatih/Lock/Lock (846).wav
# DataLatih/Lock/Lock (847).wav
# DataLatih/Lock/Lock (848).wav
# DataLatih/Lock/Lock (849).wav
# DataLatih/Lock/Lock (850).wav
# DataLatih/Lock/Lock (851).wav
# DataLatih/Lock/Lock (852).wav
# DataLatih/Lock/Lock (853).wav
# DataLatih/Lock/Lock (854).wav
# DataLatih/Lock/Lock (855).wav
# DataLatih/Lock/Lock (856).wav
# DataLatih/Lock/Lock (857).wav
# DataLatih/Lock/Lock (858).wav
# DataLatih/Lock/Lock (859).wav
# DataLatih/Lock/Lock (860).wav
# DataLatih/Lock/Lock (861).wav
# DataLatih/Lock/Lock (862).wav
# DataLatih/Lock/Lock (863).wav
# DataLatih/Lock/Lock (864).wav
# DataLatih/Lock/Lock (865).wav
# DataLatih/Lock/Lock (866).wav
# DataLatih/Lock/Lock (867).wav
# DataLatih/Lock/Lock (868).wav
# DataLatih/Lock/Lock (869).wav
# DataLatih/Lock/Lock (870).wav
# DataLatih/Lock/Lock (871).wav
# DataLatih/Lock/Lock (872).wav
# DataLatih/Lock/Lock (873).wav
# DataLatih/Lock/Lock (874).wav
# DataLatih/Lock/Lock (875).wav
# DataLatih/Lock/Lock (876).wav
# DataLatih/Lock/Lock (877).wav
# DataLatih/Lock/Lock (878).wav
# DataLatih/Lock/Lock (879).wav
# DataLatih/Lock/Lock (880).wav
# DataLatih/Lock/Lock (881).wav
# DataLatih/Lock/Lock (882).wav
# DataLatih/Lock/Lock (883).wav
# DataLatih/Lock/Lock (884).wav
# DataLatih/Lock/Lock (885).wav
# DataLatih/Lock/Lock (886).wav
# DataLatih/Lock/Lock (887).wav
# DataLatih/Lock/Lock (888).wav
# DataLatih/Lock/Lock (889).wav
# DataLatih/Lock/Lock (890).wav
# DataLatih/Lock/Lock (891).wav
# DataLatih/Lock/Lock (892).wav
# DataLatih/Lock/Lock (893).wav
# DataLatih/Lock/Lock (894).wav
# DataLatih/Lock/Lock (895).wav
# DataLatih/Lock/Lock (896).wav
# DataLatih/Lock/Lock (897).wav
# DataLatih/Lock/Lock (898).wav
# DataLatih/Lock/Lock (899).wav
# DataLatih/Lock/Lock (900).wav
# DataLatih/Unlock/Unlock (721).wav
# DataLatih/Unlock/Unlock (722).wav
# DataLatih/Unlock/Unlock (723).wav
# DataLatih/Unlock/Unlock (724).wav
# DataLatih/Unlock/Unlock (725).wav
# DataLatih/Unlock/Unlock (726).wav
# DataLatih/Unlock/Unlock (727).wav
# DataLatih/Unlock/Unlock (728).wav
# DataLatih/Unlock/Unlock (729).wav
# DataLatih/Unlock/Unlock (730).wav
# DataLatih/Unlock/Unlock (731).wav
# DataLatih/Unlock/Unlock (732).wav
# DataLatih/Unlock/Unlock (733).wav
# DataLatih/Unlock/Unlock (734).wav
# DataLatih/Unlock/Unlock (735).wav
# DataLatih/Unlock/Unlock (736).wav
# DataLatih/Unlock/Unlock (737).wav
# DataLatih/Unlock/Unlock (738).wav
# DataLatih/Unlock/Unlock (739).wav
# DataLatih/Unlock/Unlock (740).wav
# DataLatih/Unlock/Unlock (741).wav
# DataLatih/Unlock/Unlock (742).wav
# DataLatih/Unlock/Unlock (743).wav
# DataLatih/Unlock/Unlock (744).wav
# DataLatih/Unlock/Unlock (745).wav
# DataLatih/Unlock/Unlock (746).wav
# DataLatih/Unlock/Unlock (747).wav
# DataLatih/Unlock/Unlock (748).wav
# DataLatih/Unlock/Unlock (749).wav
# DataLatih/Unlock/Unlock (750).wav
# DataLatih/Unlock/Unlock (751).wav
# DataLatih/Unlock/Unlock (752).wav
# DataLatih/Unlock/Unlock (753).wav
# DataLatih/Unlock/Unlock (754).wav
# DataLatih/Unlock/Unlock (755).wav
# DataLatih/Unlock/Unlock (756).wav
# DataLatih/Unlock/Unlock (757).wav
# DataLatih/Unlock/Unlock (758).wav
# DataLatih/Unlock/Unlock (759).wav
# DataLatih/Unlock/Unlock (760).wav
# DataLatih/Unlock/Unlock (761).wav
# DataLatih/Unlock/Unlock (762).wav
# DataLatih/Unlock/Unlock (763).wav
# DataLatih/Unlock/Unlock (764).wav
# DataLatih/Unlock/Unlock (765).wav
# DataLatih/Unlock/Unlock (766).wav
# DataLatih/Unlock/Unlock (767).wav
# DataLatih/Unlock/Unlock (768).wav
# DataLatih/Unlock/Unlock (769).wav
# DataLatih/Unlock/Unlock (770).wav
# DataLatih/Unlock/Unlock (771).wav
# DataLatih/Unlock/Unlock (772).wav
# DataLatih/Unlock/Unlock (773).wav
# DataLatih/Unlock/Unlock (774).wav
# DataLatih/Unlock/Unlock (775).wav
# DataLatih/Unlock/Unlock (776).wav
# DataLatih/Unlock/Unlock (777).wav
# DataLatih/Unlock/Unlock (778).wav
# DataLatih/Unlock/Unlock (779).wav
# DataLatih/Unlock/Unlock (780).wav
# DataLatih/Unlock/Unlock (781).wav
# DataLatih/Unlock/Unlock (782).wav
# DataLatih/Unlock/Unlock (783).wav
# DataLatih/Unlock/Unlock (784).wav
# DataLatih/Unlock/Unlock (785).wav
# DataLatih/Unlock/Unlock (786).wav
# DataLatih/Unlock/Unlock (787).wav
# DataLatih/Unlock/Unlock (788).wav
# DataLatih/Unlock/Unlock (789).wav
# DataLatih/Unlock/Unlock (790).wav
# DataLatih/Unlock/Unlock (791).wav
# DataLatih/Unlock/Unlock (792).wav
# DataLatih/Unlock/Unlock (793).wav
# DataLatih/Unlock/Unlock (794).wav
# DataLatih/Unlock/Unlock (795).wav
# DataLatih/Unlock/Unlock (796).wav
# DataLatih/Unlock/Unlock (797).wav
# DataLatih/Unlock/Unlock (798).wav
# DataLatih/Unlock/Unlock (799).wav
# DataLatih/Unlock/Unlock (800).wav
# DataLatih/Unlock/Unlock (801).wav
# DataLatih/Unlock/Unlock (802).wav
# DataLatih/Unlock/Unlock (803).wav
# DataLatih/Unlock/Unlock (804).wav
# DataLatih/Unlock/Unlock (805).wav
# DataLatih/Unlock/Unlock (806).wav
# DataLatih/Unlock/Unlock (807).wav
# DataLatih/Unlock/Unlock (808).wav
# DataLatih/Unlock/Unlock (809).wav
# DataLatih/Unlock/Unlock (810).wav
# DataLatih/Unlock/Unlock (811).wav
# DataLatih/Unlock/Unlock (812).wav
# DataLatih/Unlock/Unlock (813).wav
# DataLatih/Unlock/Unlock (814).wav
# DataLatih/Unlock/Unlock (815).wav
# DataLatih/Unlock/Unlock (816).wav
# DataLatih/Unlock/Unlock (817).wav
# DataLatih/Unlock/Unlock (818).wav
# DataLatih/Unlock/Unlock (819).wav
# DataLatih/Unlock/Unlock (820).wav
# DataLatih/Unlock/Unlock (821).wav
# DataLatih/Unlock/Unlock (822).wav
# DataLatih/Unlock/Unlock (823).wav
# DataLatih/Unlock/Unlock (824).wav
# DataLatih/Unlock/Unlock (825).wav
# DataLatih/Unlock/Unlock (826).wav
# DataLatih/Unlock/Unlock (827).wav
# DataLatih/Unlock/Unlock (828).wav
# DataLatih/Unlock/Unlock (829).wav
# DataLatih/Unlock/Unlock (830).wav
# DataLatih/Unlock/Unlock (831).wav
# DataLatih/Unlock/Unlock (832).wav
# DataLatih/Unlock/Unlock (833).wav
# DataLatih/Unlock/Unlock (834).wav
# DataLatih/Unlock/Unlock (835).wav
# DataLatih/Unlock/Unlock (836).wav
# DataLatih/Unlock/Unlock (837).wav
# DataLatih/Unlock/Unlock (838).wav
# DataLatih/Unlock/Unlock (839).wav
# DataLatih/Unlock/Unlock (840).wav
# DataLatih/Unlock/Unlock (841).wav
# DataLatih/Unlock/Unlock (842).wav
# DataLatih/Unlock/Unlock (843).wav
# DataLatih/Unlock/Unlock (844).wav
# DataLatih/Unlock/Unlock (845).wav
# DataLatih/Unlock/Unlock (846).wav
# DataLatih/Unlock/Unlock (847).wav
# DataLatih/Unlock/Unlock (848).wav
# DataLatih/Unlock/Unlock (849).wav
# DataLatih/Unlock/Unlock (850).wav
# DataLatih/Unlock/Unlock (851).wav
# DataLatih/Unlock/Unlock (852).wav
# DataLatih/Unlock/Unlock (853).wav
# DataLatih/Unlock/Unlock (854).wav
# DataLatih/Unlock/Unlock (855).wav
# DataLatih/Unlock/Unlock (856).wav
# DataLatih/Unlock/Unlock (857).wav
# DataLatih/Unlock/Unlock (858).wav
# DataLatih/Unlock/Unlock (859).wav
# DataLatih/Unlock/Unlock (860).wav
# DataLatih/Unlock/Unlock (861).wav
# DataLatih/Unlock/Unlock (862).wav
# DataLatih/Unlock/Unlock (863).wav
# DataLatih/Unlock/Unlock (864).wav
# DataLatih/Unlock/Unlock (865).wav
# DataLatih/Unlock/Unlock (866).wav
# DataLatih/Unlock/Unlock (867).wav
# DataLatih/Unlock/Unlock (868).wav
# DataLatih/Unlock/Unlock (869).wav
# DataLatih/Unlock/Unlock (870).wav
# DataLatih/Unlock/Unlock (871).wav
# DataLatih/Unlock/Unlock (872).wav
# DataLatih/Unlock/Unlock (873).wav
# DataLatih/Unlock/Unlock (874).wav
# DataLatih/Unlock/Unlock (875).wav
# DataLatih/Unlock/Unlock (876).wav
# DataLatih/Unlock/Unlock (877).wav
# DataLatih/Unlock/Unlock (878).wav
# DataLatih/Unlock/Unlock (879).wav
# DataLatih/Unlock/Unlock (880).wav
# DataLatih/Unlock/Unlock (881).wav
# DataLatih/Unlock/Unlock (882).wav
# DataLatih/Unlock/Unlock (883).wav
# DataLatih/Unlock/Unlock (884).wav
# DataLatih/Unlock/Unlock (885).wav
# DataLatih/Unlock/Unlock (886).wav
# DataLatih/Unlock/Unlock (887).wav
# DataLatih/Unlock/Unlock (888).wav
# DataLatih/Unlock/Unlock (889).wav
# DataLatih/Unlock/Unlock (890).wav
# DataLatih/Unlock/Unlock (891).wav
# DataLatih/Unlock/Unlock (892).wav
# DataLatih/Unlock/Unlock (893).wav
# DataLatih/Unlock/Unlock (894).wav
# DataLatih/Unlock/Unlock (895).wav
# DataLatih/Unlock/Unlock (896).wav
# DataLatih/Unlock/Unlock (897).wav
# DataLatih/Unlock/Unlock (898).wav
# DataLatih/Unlock/Unlock (899).wav
# DataLatih/Unlock/Unlock (900).wav
